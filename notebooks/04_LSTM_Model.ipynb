# %% [markdown]
# # 04 - LSTM Model Training
#
# This notebook trains the LSTM composer classification model.

# %%
import sys
from pathlib import Path

# Add the project root to Python path for proper imports
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
sys.path.insert(0, str(project_root / 'src'))

import numpy as np

from src.utils.config import *
from src.utils.helpers import set_random_seed
from src.training import train_lstm_model

set_random_seed()
print("LSTM training notebook ready!")

# %%
# Load LSTM features
data = np.load(LSTM_FEATURES_FILE, allow_pickle=True)
X_train = data['features']
y_train = data['labels']
print(f"Loaded training data: {X_train.shape}")

# %%
# Load validation and test data
# (Assuming they were saved separately or need to be regenerated)
print("Load validation and test data from feature extraction step")

# %%
# Train LSTM model
lstm_input_shape = (SEQUENCE_LENGTH, 3)
lstm_summary, lstm_metrics = train_lstm_model(
    X_train, y_train, X_val, y_val, X_test, y_test,
    input_shape=lstm_input_shape,
    num_classes=NUM_CLASSES,
    model_type='standard'
)
print("LSTM training completed!")
