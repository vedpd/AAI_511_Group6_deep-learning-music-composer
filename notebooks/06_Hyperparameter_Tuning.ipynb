# %% [markdown]
# # 06 - Hyperparameter Tuning
#
# This notebook performs hyperparameter tuning for both LSTM and CNN models.

# %%
import sys
from pathlib import Path

# Add the project root to Python path for proper imports
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

import numpy as np
import itertools

from src.utils.config import *
from src.utils.config import ensure_directories
from src.utils.helpers import set_random_seed
from src.models import create_lstm_model, create_cnn_model
from src.training import LSTMTrainer, CNNTrainer

# Create output directories
ensure_directories()

set_random_seed()
print("Hyperparameter tuning notebook ready!")

# %%
# Define hyperparameter grids
lstm_params = {
    'hidden_units': [128, 256, 512],
    'dropout': [0.2, 0.3, 0.5],
    'learning_rate': [0.001, 0.0001, 0.00001]
}

cnn_params = {
    'filters': [[32, 64, 128], [64, 128, 256], [128, 256, 512]],
    'dropout': [0.2, 0.3, 0.5],
    'learning_rate': [0.001, 0.0001, 0.00001]
}

print("Hyperparameter grids defined")

# %%
# Example: Grid search for LSTM
# (This is a template - actual implementation would require loading data)
print("Hyperparameter tuning template:")
print("1. Load training/validation data")
print("2. Iterate through parameter combinations")
print("3. Train model with each combination")
print("4. Evaluate on validation set")
print("5. Select best parameters")
print("6. Retrain on combined train+val with best parameters")

# %%
# Example code structure for hyperparameter tuning
def tune_lstm_model(X_train, y_train, X_val, y_val, param_grid):
    best_score = 0
    best_params = {}
    
    for hidden_units in param_grid['hidden_units']:
        for dropout in param_grid['dropout']:
            for lr in param_grid['learning_rate']:
                # Create and train model
                model = create_lstm_model(X_train.shape[1:], NUM_CLASSES)
                trainer = LSTMTrainer(model, learning_rate=lr, dropout=dropout)
                # Train for few epochs
                # Evaluate
                # Update best if improved
                pass
    
    return best_params, best_score

print("Hyperparameter tuning function defined")
